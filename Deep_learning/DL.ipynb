# %%
"""
Fashion-MNIST Neural Network Training
Dataset: 70,000 images of fashion items (10 classes)
Target: 90%+ accuracy
"""

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# ==================== DATA LOADING ====================
print("\n[1/6] Loading Fashion-MNIST dataset...")
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Class names for Fashion-MNIST
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print(f"Training set: {x_train.shape[0]} images")
print(f"Test set: {x_test.shape[0]} images")
print(f"Image size: {x_train.shape[1]}x{x_train.shape[2]} pixels")

# ==================== DATA PREPROCESSING ====================
print("\n[2/6] Preprocessing data...")

# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape for CNN (add channel dimension)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Convert labels to one-hot encoding
y_train_cat = keras.utils.to_categorical(y_train, 10)
y_test_cat = keras.utils.to_categorical(y_test, 10)

print(f"Training data shape: {x_train.shape}")
print(f"Training labels shape: {y_train_cat.shape}")

# ==================== MODEL ARCHITECTURE ====================
print("\n[3/6] Building neural network model...")

model = keras.Sequential([
    # Convolutional Block 1
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    # Convolutional Block 2
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    # Convolutional Block 3
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    
    # Dense Layers
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='softmax')
])

# Display model architecture
model.summary()

# ==================== COMPILE MODEL ====================
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ==================== CALLBACKS ====================
# Early stopping to prevent overfitting
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# Learning rate reduction on plateau
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

# ==================== TRAINING ====================
print("\n[4/6] Training the model...")
history = model.fit(
    x_train, y_train_cat,
    batch_size=128,
    epochs=30,
    validation_split=0.15,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

# ==================== EVALUATION ====================
print("\n[5/6] Evaluating model performance...")
test_loss, test_accuracy = model.evaluate(x_test, y_test_cat, verbose=0)

print(f"\n{'='*50}")
print(f"TEST ACCURACY: {test_accuracy*100:.2f}%")
print(f"TEST LOSS: {test_loss:.4f}")
print(f"{'='*50}")

# Make predictions
y_pred = model.predict(x_test, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_classes, target_names=class_names))

# ==================== VISUALIZATION ====================
print("\n[6/6] Generating visualizations...")

# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy plot
axes[0].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
axes[0].set_title('Model Accuracy', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss plot
axes[1].plot(history.history['loss'], label='Training Loss', linewidth=2)
axes[1].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
axes[1].set_title('Model Loss', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('training_history.png', dpi=300, bbox_inches='tight')
print("✓ Saved: training_history.png")

# Confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix', fontsize=16, fontweight='bold')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
print("✓ Saved: confusion_matrix.png")

# Sample predictions
fig, axes = plt.subplots(3, 5, figsize=(15, 9))
axes = axes.ravel()

for i in range(15):
    idx = np.random.randint(0, len(x_test))
    axes[i].imshow(x_test[idx].reshape(28, 28), cmap='gray')
    true_label = class_names[y_test[idx]]
    pred_label = class_names[y_pred_classes[idx]]
    color = 'green' if y_test[idx] == y_pred_classes[idx] else 'red'
    axes[i].set_title(f'True: {true_label}\nPred: {pred_label}', 
                      color=color, fontsize=9)
    axes[i].axis('off')

plt.suptitle('Sample Predictions (Green=Correct, Red=Wrong)', 
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('sample_predictions.png', dpi=300, bbox_inches='tight')
print("✓ Saved: sample_predictions.png")

plt.show()

# ==================== SAVE MODEL ====================
model.save('fashion_mnist_model.keras')
print("\n✓ Model saved as: fashion_mnist_model.keras")

print("\n" + "="*50)
print("TRAINING COMPLETE!")
print("="*50)
print(f"Final Test Accuracy: {test_accuracy*100:.2f}%")
print(f"Target Met: {'YES ✓' if test_accuracy >= 0.90 else 'NO ✗'}")
print("="*50)
# Out:
# TensorFlow version: 2.20.0
# GPU Available: []
#
# [1/6] Loading Fashion-MNIST dataset...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 9s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Training set: 60000 images
# Test set: 10000 images
# Image size: 28x28 pixels
#
# [2/6] Preprocessing data...
# Training data shape: (60000, 28, 28, 1)
# Training labels shape: (60000, 10)
#
# [3/6] Building neural network model...
# c:\Users\abhay\OneDrive\Desktop\learn_cdx\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 26, 26, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 11, 11, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 3, 3, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 423,946 (1.62 MB)
#  Trainable params: 422,986 (1.61 MB)
#  Non-trainable params: 960 (3.75 KB)
# [4/6] Training the model...
# Epoch 1/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - accuracy: 0.7288 - loss: 0.7648 - val_accuracy: 0.6801 - val_loss: 0.8814 - learning_rate: 0.0010
# Epoch 2/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.8325 - loss: 0.4609 - val_accuracy: 0.8634 - val_loss: 0.3566 - learning_rate: 0.0010
# Epoch 3/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.8569 - loss: 0.3988 - val_accuracy: 0.8851 - val_loss: 0.3107 - learning_rate: 0.0010
# Epoch 4/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.8687 - loss: 0.3652 - val_accuracy: 0.8848 - val_loss: 0.3066 - learning_rate: 0.0010
# Epoch 5/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - accuracy: 0.8774 - loss: 0.3382 - val_accuracy: 0.8983 - val_loss: 0.2846 - learning_rate: 0.0010
# Epoch 6/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.8831 - loss: 0.3192 - val_accuracy: 0.8954 - val_loss: 0.2848 - learning_rate: 0.0010
# Epoch 7/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 72s 180ms/step - accuracy: 0.8863 - loss: 0.3103 - val_accuracy: 0.8881 - val_loss: 0.2932 - learning_rate: 0.0010
# Epoch 8/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 31s 77ms/step - accuracy: 0.8924 - loss: 0.2978 - val_accuracy: 0.9068 - val_loss: 0.2523 - learning_rate: 0.0010
# Epoch 9/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8951 - loss: 0.2868 - val_accuracy: 0.8993 - val_loss: 0.2656 - learning_rate: 0.0010
# Epoch 10/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8970 - loss: 0.2801 - val_accuracy: 0.9010 - val_loss: 0.2662 - learning_rate: 0.0010
# Epoch 11/30
# 397/399 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8966 - loss: 0.2737
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.8977 - loss: 0.2741 - val_accuracy: 0.9061 - val_loss: 0.2570 - learning_rate: 0.0010
# Epoch 12/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - accuracy: 0.9071 - loss: 0.2544 - val_accuracy: 0.9107 - val_loss: 0.2407 - learning_rate: 5.0000e-04
# Epoch 13/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9115 - loss: 0.2434 - val_accuracy: 0.9111 - val_loss: 0.2411 - learning_rate: 5.0000e-04
# Epoch 14/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9119 - loss: 0.2414 - val_accuracy: 0.9130 - val_loss: 0.2357 - learning_rate: 5.0000e-04
# Epoch 15/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.9111 - loss: 0.2404 - val_accuracy: 0.9172 - val_loss: 0.2297 - learning_rate: 5.0000e-04
# Epoch 16/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9140 - loss: 0.2325 - val_accuracy: 0.9143 - val_loss: 0.2362 - learning_rate: 5.0000e-04
# Epoch 17/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9155 - loss: 0.2286 - val_accuracy: 0.9008 - val_loss: 0.2638 - learning_rate: 5.0000e-04
# Epoch 18/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9172 - loss: 0.2198
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.9168 - loss: 0.2222 - val_accuracy: 0.9168 - val_loss: 0.2297 - learning_rate: 5.0000e-04
# Epoch 19/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.9199 - loss: 0.2171 - val_accuracy: 0.9216 - val_loss: 0.2176 - learning_rate: 2.5000e-04
# Epoch 20/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9214 - loss: 0.2129 - val_accuracy: 0.9209 - val_loss: 0.2197 - learning_rate: 2.5000e-04
# Epoch 21/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9223 - loss: 0.2083 - val_accuracy: 0.9183 - val_loss: 0.2267 - learning_rate: 2.5000e-04
# Epoch 22/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9205 - loss: 0.2135
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9211 - loss: 0.2103 - val_accuracy: 0.9154 - val_loss: 0.2368 - learning_rate: 2.5000e-04
# Epoch 23/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9252 - loss: 0.2020 - val_accuracy: 0.9249 - val_loss: 0.2120 - learning_rate: 1.2500e-04
# Epoch 24/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9251 - loss: 0.2014 - val_accuracy: 0.9223 - val_loss: 0.2122 - learning_rate: 1.2500e-04
# Epoch 25/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9268 - loss: 0.1970 - val_accuracy: 0.9234 - val_loss: 0.2105 - learning_rate: 1.2500e-04
# Epoch 26/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9262 - loss: 0.1991 - val_accuracy: 0.9246 - val_loss: 0.2118 - learning_rate: 1.2500e-04
# Epoch 27/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9286 - loss: 0.1946 - val_accuracy: 0.9239 - val_loss: 0.2122 - learning_rate: 1.2500e-04
# Epoch 28/30
# 398/399 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9252 - loss: 0.1986
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9272 - loss: 0.1966 - val_accuracy: 0.9230 - val_loss: 0.2132 - learning_rate: 1.2500e-04
# Epoch 29/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9275 - loss: 0.1924 - val_accuracy: 0.9247 - val_loss: 0.2079 - learning_rate: 6.2500e-05
# Epoch 30/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.9271 - loss: 0.1929 - val_accuracy: 0.9259 - val_loss: 0.2070 - learning_rate: 6.2500e-05
#
# [5/6] Evaluating model performance...
#
# ==================================================
# TEST ACCURACY: 92.21%
# TEST LOSS: 0.2172
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.89      0.86      0.88      1000
#      Trouser       1.00      0.98      0.99      1000
#     Pullover       0.89      0.89      0.89      1000
#        Dress       0.91      0.94      0.92      1000
#         Coat       0.88      0.87      0.88      1000
#       Sandal       0.99      0.97      0.98      1000
#        Shirt       0.76      0.78      0.77      1000
#      Sneaker       0.95      0.98      0.96      1000
#          Bag       0.99      0.99      0.99      1000
#   Ankle boot       0.97      0.96      0.97      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
#
#
# [6/6] Generating visualizations...
# ✓ Saved: training_history.png
# ✓ Saved: confusion_matrix.png
# ✓ Saved: sample_predictions.png
# ✓ Model saved as: fashion_mnist_model.keras
#
# ==================================================
# TRAINING COMPLETE!
# ==================================================
# Final Test Accuracy: 92.21%
# Target Met: YES ✓
# ==================================================

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.20.0
# GPU Available: []

# %%
# ==================== DATA LOADING ====================
print("\n[1/6] Loading Fashion-MNIST dataset...")
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Class names for Fashion-MNIST
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print(f"Training set: {x_train.shape[0]} images")
print(f"Test set: {x_test.shape[0]} images")
print(f"Image size: {x_train.shape[1]}x{x_train.shape[2]} pixels")
# Out:
# [1/6] Loading Fashion-MNIST dataset...
# Training set: 60000 images
# Test set: 10000 images
# Image size: 28x28 pixels

# %%
# ==================== DATA PREPROCESSING ====================
print("\n[2/6] Preprocessing data...")

# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape for CNN (add channel dimension)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Convert labels to one-hot encoding
y_train_cat = keras.utils.to_categorical(y_train, 10)
y_test_cat = keras.utils.to_categorical(y_test, 10)

print(f"Training data shape: {x_train.shape}")
print(f"Training labels shape: {y_train_cat.shape}")
# Out:
# [2/6] Preprocessing data...
# Training data shape: (60000, 28, 28, 1)
# Training labels shape: (60000, 10)

# %%
# ==================== MODEL ARCHITECTURE ====================
print("\n[3/6] Building neural network model...")

model = keras.Sequential([
    # Convolutional Block 1
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    # Convolutional Block 2
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    # Convolutional Block 3
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    
    # Dense Layers
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='softmax')
])

# Display model architecture
model.summary()
# Out:
# [3/6] Building neural network model...
# c:\Users\abhay\OneDrive\Desktop\learn_cdx\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 26, 26, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 11, 11, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 3, 3, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 423,946 (1.62 MB)
#  Trainable params: 422,986 (1.61 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# ==================== COMPILE MODEL ====================
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# ==================== CALLBACKS ====================
# Early stopping to prevent overfitting
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# Learning rate reduction on plateau
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

# %%
# ==================== TRAINING ====================
print("\n[4/6] Training the model...")
history = model.fit(
    x_train, y_train_cat,
    batch_size=128,
    epochs=30,
    validation_split=0.15,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# [4/6] Training the model...
# Epoch 1/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.7355 - loss: 0.7530 - val_accuracy: 0.6071 - val_loss: 1.2025 - learning_rate: 0.0010
# Epoch 2/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 70s 177ms/step - accuracy: 0.8324 - loss: 0.4619 - val_accuracy: 0.8583 - val_loss: 0.3575 - learning_rate: 0.0010
# Epoch 3/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 24s 59ms/step - accuracy: 0.8537 - loss: 0.3975 - val_accuracy: 0.8759 - val_loss: 0.3247 - learning_rate: 0.0010
# Epoch 4/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.8694 - loss: 0.3586 - val_accuracy: 0.8889 - val_loss: 0.2913 - learning_rate: 0.0010
# Epoch 5/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 43s 107ms/step - accuracy: 0.8793 - loss: 0.3334 - val_accuracy: 0.8893 - val_loss: 0.2890 - learning_rate: 0.0010
# Epoch 6/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.8833 - loss: 0.3223 - val_accuracy: 0.8961 - val_loss: 0.2757 - learning_rate: 0.0010
# Epoch 7/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - accuracy: 0.8879 - loss: 0.3074 - val_accuracy: 0.9046 - val_loss: 0.2661 - learning_rate: 0.0010
# Epoch 8/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 34s 85ms/step - accuracy: 0.8939 - loss: 0.2930 - val_accuracy: 0.8966 - val_loss: 0.2763 - learning_rate: 0.0010
# Epoch 9/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 76s 191ms/step - accuracy: 0.8961 - loss: 0.2855 - val_accuracy: 0.8921 - val_loss: 0.2837 - learning_rate: 0.0010
# Epoch 10/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8994 - loss: 0.2770
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.8979 - loss: 0.2787 - val_accuracy: 0.8921 - val_loss: 0.2774 - learning_rate: 0.0010
# Epoch 11/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.9070 - loss: 0.2567 - val_accuracy: 0.9026 - val_loss: 0.2662 - learning_rate: 5.0000e-04
# Epoch 12/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.9086 - loss: 0.2493 - val_accuracy: 0.9029 - val_loss: 0.2643 - learning_rate: 5.0000e-04
# Epoch 13/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9114 - loss: 0.2419 - val_accuracy: 0.8888 - val_loss: 0.2994 - learning_rate: 5.0000e-04
# Epoch 14/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.9127 - loss: 0.2354 - val_accuracy: 0.9121 - val_loss: 0.2401 - learning_rate: 5.0000e-04
# Epoch 15/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.9132 - loss: 0.2340 - val_accuracy: 0.8948 - val_loss: 0.2916 - learning_rate: 5.0000e-04
# Epoch 16/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.9143 - loss: 0.2303 - val_accuracy: 0.9194 - val_loss: 0.2256 - learning_rate: 5.0000e-04
# Epoch 17/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 32s 58ms/step - accuracy: 0.9155 - loss: 0.2290 - val_accuracy: 0.9089 - val_loss: 0.2477 - learning_rate: 5.0000e-04
# Epoch 18/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.9173 - loss: 0.2238 - val_accuracy: 0.9134 - val_loss: 0.2373 - learning_rate: 5.0000e-04
# Epoch 19/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9173 - loss: 0.2226 - val_accuracy: 0.9188 - val_loss: 0.2235 - learning_rate: 5.0000e-04
# Epoch 20/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.9192 - loss: 0.2178 - val_accuracy: 0.9150 - val_loss: 0.2352 - learning_rate: 5.0000e-04
# Epoch 21/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 43s 66ms/step - accuracy: 0.9201 - loss: 0.2172 - val_accuracy: 0.9002 - val_loss: 0.2736 - learning_rate: 5.0000e-04
# Epoch 22/30
# 398/399 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9207 - loss: 0.2127
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 65ms/step - accuracy: 0.9214 - loss: 0.2128 - val_accuracy: 0.9003 - val_loss: 0.2760 - learning_rate: 5.0000e-04
# Epoch 23/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 25s 62ms/step - accuracy: 0.9245 - loss: 0.2051 - val_accuracy: 0.9172 - val_loss: 0.2329 - learning_rate: 2.5000e-04
# Epoch 24/30
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 26s 65ms/step - accuracy: 0.9263 - loss: 0.1987 - val_accuracy: 0.9136 - val_loss: 0.2434 - learning_rate: 2.5000e-04

# %%
# ==================== EVALUATION ====================
print("\n[5/6] Evaluating model performance...")
test_loss, test_accuracy = model.evaluate(x_test, y_test_cat, verbose=0)

print(f"\n{'='*50}")
print(f"TEST ACCURACY: {test_accuracy*100:.2f}%")
print(f"TEST LOSS: {test_loss:.4f}")
print(f"{'='*50}")

# Make predictions
y_pred = model.predict(x_test, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_classes, target_names=class_names))
# Out:
# [5/6] Evaluating model performance...
#
# ==================================================
# TEST ACCURACY: 91.63%
# TEST LOSS: 0.2314
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.90      0.83      0.86      1000
#      Trouser       0.99      0.98      0.99      1000
#     Pullover       0.88      0.89      0.88      1000
#        Dress       0.91      0.92      0.91      1000
#         Coat       0.86      0.90      0.88      1000
#       Sandal       0.99      0.97      0.98      1000
#        Shirt       0.75      0.77      0.76      1000
#      Sneaker       0.93      0.99      0.96      1000
#          Bag       0.99      0.98      0.98      1000
#   Ankle boot       0.98      0.94      0.96      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000

# %%
# ==================== VISUALIZATION ====================
print("\n[6/6] Generating visualizations...")

# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy plot
axes[0].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
axes[0].set_title('Model Accuracy', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss plot
axes[1].plot(history.history['loss'], label='Training Loss', linewidth=2)
axes[1].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
axes[1].set_title('Model Loss', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('training_history.png', dpi=300, bbox_inches='tight')
print("✓ Saved: training_history.png")

# Confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix', fontsize=16, fontweight='bold')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
print("✓ Saved: confusion_matrix.png")

# Sample predictions
fig, axes = plt.subplots(3, 5, figsize=(15, 9))
axes = axes.ravel()

for i in range(15):
    idx = np.random.randint(0, len(x_test))
    axes[i].imshow(x_test[idx].reshape(28, 28), cmap='gray')
    true_label = class_names[y_test[idx]]
    pred_label = class_names[y_pred_classes[idx]]
    color = 'green' if y_test[idx] == y_pred_classes[idx] else 'red'
    axes[i].set_title(f'True: {true_label}\nPred: {pred_label}', 
                      color=color, fontsize=9)
    axes[i].axis('off')

plt.suptitle('Sample Predictions (Green=Correct, Red=Wrong)', 
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('sample_predictions.png', dpi=300, bbox_inches='tight')
print("✓ Saved: sample_predictions.png")

plt.show()
# Out:
# [6/6] Generating visualizations...
# ✓ Saved: training_history.png
# ✓ Saved: confusion_matrix.png
# ✓ Saved: sample_predictions.png

# %%
# ==================== SAVE MODEL ====================
model.save('fashion_mnist_model.keras')
print("\n✓ Model saved as: fashion_mnist_model.keras")

print("\n" + "="*50)
print("TRAINING COMPLETE!")
print("="*50)
print(f"Final Test Accuracy: {test_accuracy*100:.2f}%")
print(f"Target Met: {'YES ✓' if test_accuracy >= 0.90 else 'NO ✗'}")
print("="*50)
# Out:
# ✓ Model saved as: fashion_mnist_model.keras
#
# ==================================================
# TRAINING COMPLETE!
# ==================================================
# Final Test Accuracy: 91.63%
# Target Met: YES ✓
# ==================================================
